# %% [markdown]
# **2.1 Building the circuit to prepare the Bell state**

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute, Aer

q = QuantumRegister(2)
c = ClassicalRegister(2)
qc = QuantumCircuit(q,c)

# Applying Hadamard to first qubit
qc.h(q[0])

# Applying CNOT gate where first qubit is control bit, and second qubit is target bit
qc.cx(q[0], q[1])

qc.draw(output='mpl')

# %%
# Verifying that bell state has been obtained
qc.measure(q,[1,0])
job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
counts = job.result().get_counts(qc)
print(counts)
# Out:
# {'00': 511, '11': 489}

# %%
from random import randrange

# function to introduce error with a probability p
def chance(prob):
    '''
    params:
        prob(float): value of probability
        
    returns:
        cause(bool): 1 or 0
    '''
    limiting_number = int(100 * prob )
    random_number = randrange(100)
    return random_number < limiting_number

# %% [markdown]
# **2.2  Adding Error Gate with probability  p = 0.4**

# %%
q = QuantumRegister(2)
c = ClassicalRegister(2)
qc = QuantumCircuit(q,c)

qc.h(q[0])

# Applying error gate to individual bits
# here for each Qubit
# - probability of  X-gate acting on it is 0.2 = (0.4 * 0.5)
# - probability of Z-gate acting on it is 0.2 = (0.4 * 0.5)
for i in [0,1]:
    if chance(0.4):
        if randrange(2) == 0:
            qc.x(q[i])
            print('X Error gate acts on {} qubit'.format(i))
        else:
            qc.z(q[i])
            print('Z Error gate acts on {} qubit'.format(i))

qc.cx(q[0], q[1])

qc.draw(output='mpl')
# Out:
# Z Error gate acts on 0 qubit

# %%
# Cases explained here - https://bit.ly/3pkAzce

# Printing the State Vector and measured outcomes for confirmation
job = execute(qc, Aer.get_backend('statevector_simulator'))
for v in job.result().get_statevector(experiment=qc, decimals=2):
    print(v)


qc.measure(q,[1,0])
job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
counts = job.result().get_counts(qc)
print(counts)
# Out:
# (0.7071067811865476+0j)
# (-0+0j)
# 0j
# (-0.7071067811865475+0j)
# {'00': 509, '11': 491}

# %% [markdown]
#  **Repeating the measrurements several times, to verify theoretical expectations mentioned [here](https://bit.ly/3pkAzce)**

# %%
n1 = 0 # Number of times we obtain |00> +/- |11>/root(2), theoretical expectations = 80 times out of 100
n2 = 0 # Number of times we obtain |01> +/- |10>/root(2), theoretical expectations = 20 times out of 100
for r in range(100):
    print('{} iteration'.format(r))
    q = QuantumRegister(2)
    c = ClassicalRegister(2)
    qc = QuantumCircuit(q,c)
    qc.h(q[0])
    for i in [0,1]:
        if chance(0.4):
            if randrange(2) == 0:
                qc.x(q[i])
                print('X Error gate acts on {} qubit'.format(i))
            else:
                qc.z(q[i])
                print('Z Error gate acts on {} qubit'.format(i))
    qc.cx(q[0], q[1])
    
    qc.measure(q,[1,0])
    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)
    print(counts.get('00') )
    if counts.get('00') != None:
        n1 += 1
    else:
        n2 += 1


print('Number of times |00> +/- |11>/root(2) ', n1)
print('Number of times |01> +/- |10>/root(2) ', n2)
# We see the around 20 % of the times we get |01> +/- |10>/root(2), which is caused by error gates. Now this error correction needs to be done. Also we need to keep
# in mind that there there was also a change in output in case of |00> - |11>/ root(2), but  measurements using expectation values cannot differentiate it.
# Out:
# 0 iteration
# 509
# 1 iteration
# X Error gate acts on 1 qubit
# None
# 2 iteration
# X Error gate acts on 0 qubit
# 518
# 3 iteration
# Z Error gate acts on 0 qubit
# 491
# 4 iteration
# X Error gate acts on 1 qubit
# None
# 5 iteration
# 486
# 6 iteration
# 472
# 7 iteration
# X Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 485
# 8 iteration
# Z Error gate acts on 0 qubit
# 522
# 9 iteration
# Z Error gate acts on 0 qubit
# 498
# 10 iteration
# X Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 11 iteration
# Z Error gate acts on 0 qubit
# 485
# 12 iteration
# 501
# 13 iteration
# Z Error gate acts on 1 qubit
# 531
# 14 iteration
# X Error gate acts on 1 qubit
# None
# 15 iteration
# X Error gate acts on 0 qubit
# 519
# 16 iteration
# 521
# 17 iteration
# Z Error gate acts on 0 qubit
# 523
# 18 iteration
# X Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 19 iteration
# Z Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 20 iteration
# 515
# 21 iteration
# Z Error gate acts on 1 qubit
# 469
# 22 iteration
# 515
# 23 iteration
# 522
# 24 iteration
# Z Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 25 iteration
# Z Error gate acts on 1 qubit
# 513
# 26 iteration
# 493
# 27 iteration
# X Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 28 iteration
# X Error gate acts on 0 qubit
# 499
# 29 iteration
# 487
# 30 iteration
# Z Error gate acts on 0 qubit
# 492
# 31 iteration
# Z Error gate acts on 0 qubit
# 483
# 32 iteration
# 522
# 33 iteration
# X Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 526
# 34 iteration
# 504
# 35 iteration
# 506
# 36 iteration
# 490
# 37 iteration
# 515
# 38 iteration
# 524
# 39 iteration
# X Error gate acts on 1 qubit
# None
# 40 iteration
# Z Error gate acts on 0 qubit
# 489
# 41 iteration
# 494
# 42 iteration
# Z Error gate acts on 0 qubit
# 489
# 43 iteration
# X Error gate acts on 0 qubit
# 499
# 44 iteration
# 519
# 45 iteration
# Z Error gate acts on 0 qubit
# 521
# 46 iteration
# 519
# 47 iteration
# 500
# 48 iteration
# Z Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 49 iteration
# X Error gate acts on 1 qubit
# None
# 50 iteration
# Z Error gate acts on 0 qubit
# 501
# 51 iteration
# 502
# 52 iteration
# 481
# 53 iteration
# 503
# 54 iteration
# X Error gate acts on 0 qubit
# 497
# 55 iteration
# Z Error gate acts on 1 qubit
# 509
# 56 iteration
# 515
# 57 iteration
# Z Error gate acts on 0 qubit
# 488
# 58 iteration
# 493
# 59 iteration
# X Error gate acts on 0 qubit
# 512
# 60 iteration
# Z Error gate acts on 1 qubit
# 497
# 61 iteration
# X Error gate acts on 1 qubit
# None
# 62 iteration
# X Error gate acts on 0 qubit
# 508
# 63 iteration
# 529
# 64 iteration
# X Error gate acts on 1 qubit
# None
# 65 iteration
# X Error gate acts on 0 qubit
# 530
# 66 iteration
# X Error gate acts on 0 qubit
# X Error gate acts on 1 qubit
# None
# 67 iteration
# X Error gate acts on 1 qubit
# None
# 68 iteration
# X Error gate acts on 0 qubit
# 513
# 69 iteration
# 523
# 70 iteration
# X Error gate acts on 1 qubit
# None
# 71 iteration
# 535
# 72 iteration
# Z Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 468
# 73 iteration
# Z Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 516
# 74 iteration
# 480
# 75 iteration
# 493
# 76 iteration
# Z Error gate acts on 0 qubit
# 476
# 77 iteration
# 511
# 78 iteration
# 503
# 79 iteration
# 519
# 80 iteration
# 516
# 81 iteration
# Z Error gate acts on 1 qubit
# 512
# 82 iteration
# X Error gate acts on 0 qubit
# 487
# 83 iteration
# 498
# 84 iteration
# 513
# 85 iteration
# X Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 505
# 86 iteration
# 519
# 87 iteration
# Z Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 526
# 88 iteration
# 506
# 89 iteration
# 491
# 90 iteration
# 480
# 91 iteration
# X Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# 505
# 92 iteration
# 513
# 93 iteration
# 505
# 94 iteration
# 536
# 95 iteration
# 489
# 96 iteration
# 495
# 97 iteration
# Z Error gate acts on 0 qubit
# 484
# 98 iteration
# X Error gate acts on 1 qubit
# None
# 99 iteration
# 506
# Number of times |00> +/- |11>/root(2)  83
# Number of times |01> +/- |10>/root(2)  17

# %% [markdown]
# **Here in this cell, it is shown through state vectors are indeed changed when error gates act, by running the cicuit few times and each time error gates acting differently**

# %%
for r in range(10):
    print('{} iteration'.format(r))
    q = QuantumRegister(2)
    c = ClassicalRegister(2)
    qc = QuantumCircuit(q,c)
    qc.h(q[0])
    for i in [0,1]:
        if chance(0.4):
            if randrange(2) == 0:
                qc.x(q[i])
                print('X Error gate acts on {} qubit'.format(i))
            else:
                qc.z(q[i])
                print('Z Error gate acts on {} qubit'.format(i))
    qc.cx(q[0], q[1])
    
    job = execute(qc, Aer.get_backend('statevector_simulator'))
    for v in job.result().get_statevector(experiment=qc, decimals=3):
        print('Coffecients  ',v )
    qc.measure(q,[1,0])
    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)
    
    
    print(counts )
    print()
# Out:
# 0 iteration
# X Error gate acts on 1 qubit
# Coffecients   0j
# Coffecients   (0.7071067811865475+0j)
# Coffecients   (0.7071067811865476+0j)
# Coffecients   0j
# {'01': 507, '10': 493}
#
# 1 iteration
# Z Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# Coffecients   (0.7071067811865476+0j)
# Coffecients   -0j
# Coffecients   (-0+0j)
# Coffecients   (-0.7071067811865475+0j)
# {'00': 510, '11': 490}
#
# 2 iteration
# X Error gate acts on 1 qubit
# Coffecients   0j
# Coffecients   (0.7071067811865475+0j)
# Coffecients   (0.7071067811865476+0j)
# Coffecients   0j
# {'01': 529, '10': 471}
#
# 3 iteration
# Z Error gate acts on 0 qubit
# Z Error gate acts on 1 qubit
# Coffecients   (0.7071067811865476+0j)
# Coffecients   -0j
# Coffecients   (-0+0j)
# Coffecients   (-0.7071067811865475+0j)
# {'00': 503, '11': 497}
#
# 4 iteration
# Z Error gate acts on 0 qubit
# Coffecients   (0.7071067811865476+0j)
# Coffecients   (-0+0j)
# Coffecients   0j
# Coffecients   (-0.7071067811865475+0j)
# {'00': 499, '11': 501}
#
# 5 iteration
# X Error gate acts on 0 qubit
# Coffecients   (0.7071067811865475+0j)
# Coffecients   0j
# Coffecients   0j
# Coffecients   (0.7071067811865476+0j)
# {'00': 494, '11': 506}
#
# 6 iteration
# Coffecients   (0.7071067811865476+0j)
# Coffecients   0j
# Coffecients   0j
# Coffecients   (0.7071067811865475+0j)
# {'00': 503, '11': 497}
#
# 7 iteration
# Z Error gate acts on 0 qubit
# Coffecients   (0.7071067811865476+0j)
# Coffecients   (-0+0j)
# Coffecients   0j
# Coffecients   (-0.7071067811865475+0j)
# {'00': 511, '11': 489}
#
# 8 iteration
# Z Error gate acts on 1 qubit
# Coffecients   (0.7071067811865476+0j)
# Coffecients   (-0+0j)
# Coffecients   (-0+0j)
# Coffecients   (0.7071067811865475+0j)
# {'00': 486, '11': 514}
#
# 9 iteration
# Z Error gate acts on 1 qubit
# Coffecients   (0.7071067811865476+0j)
# Coffecients   (-0+0j)
# Coffecients   (-0+0j)
# Coffecients   (0.7071067811865475+0j)
# {'00': 513, '11': 487}

# %% [markdown]
# **2.3 Correcting Bit flip and Phase flip errors using Shor's 9 bit Code**

# %%
# For Shor's Code, we require 8 ancilliary Qubits for each main Qubit,
# Hence here we require a total of  18 Qubits, where qubits with indices 0,9 are the main Qubits and the rest are ancilliary Qubits

q= QuantumRegister(18)
c = ClassicalRegister(2)
qc = QuantumCircuit(q,c)

qc.h(q[0])

# Encoding as per Shor's Algorithm
main_qubits = [0,9]
for i in main_qubits:
    qc.cx(q[i], q[i+3])
    qc.cx(q[i], q[i+6])
    
    qc.h(q[i])
    qc.h(q[i+3])
    qc.h(q[i+6])
    
    qc.cx(q[i], q[i+1])
    qc.cx(q[i+3], q[i+4])
    qc.cx(q[i+6], q[i+7])
    
    qc.cx(q[i], q[i+2])
    qc.cx(q[i+3], q[i+5])
    qc.cx(q[i+6], q[i+8])
  
qc.barrier()

# Let the error Gates act
for i in main_qubits:
        if chance(0.4):
            if randrange(2) == 0:
                qc.x(q[i])
                print('X Error gate acts on main qubit - {}'.format(i))
                
            else:
                qc.z(q[i])
                print('Z Error gate acts on main qubit - {}'.format(i))
                
                
qc.barrier()

# Applying the error correction code
for i in main_qubits:
    qc.cx(q[i], q[i+1])
    qc.cx(q[i+3], q[i+4])
    qc.cx(q[i+6], q[i+7])
    
    qc.cx(q[i], q[i+2])
    qc.cx(q[i+3], q[i+5])
    qc.cx(q[i+6], q[i+8])
    
    qc.ccx(q[i+2], q[i+1], q[i])
    qc.ccx(q[i+5],q[i+4],q[i+3])
    qc.ccx(q[i+8],q[i+7],q[i+6])
    
    qc.h(q[i])
    qc.h(q[i+3])
    qc.h(q[i+6])
    
    qc.cx(q[i], q[i+3])
    qc.cx(q[i], q[i+6])
    
    qc.ccx(q[i+6], q[i+3], q[i])
    

qc.cx(q[0], q[9])
qc.draw(output='mpl')
# Out:
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 9

# %%
# Verifying by measuing
# The output has to be |00> + |11> / root(2) as the correction has been applied

qc.measure([0,9],[1,0])
job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
counts = job.result().get_counts(qc)
print(counts)
# Out:
# {'00': 459, '11': 541}

# %% [markdown]
# **2.4 Testing by making 100 measurements, and verifying that each time the expected Bell State is obtained**

# %%
# checking 100 times
# Each time should result in |00> + |11>/root(2)

n1 = 0 # Number of times we obtain |00> + |11>/root(2), should be 100 as error correction is applied
n2 = 0 # Number of times any other result is obtained, should be 0 

for r in range(100):
    print('iteration ',r)
    q= QuantumRegister(18)
    c = ClassicalRegister(2)
    qc = QuantumCircuit(q,c)

    qc.h(q[0])

    # Encoding as per Shor's Algorithm
    main_qubits = [0,9]
    for i in main_qubits:
        qc.cx(q[i], q[i+3])
        qc.cx(q[i], q[i+6])

        qc.h(q[i])
        qc.h(q[i+3])
        qc.h(q[i+6])

        qc.cx(q[i], q[i+1])
        qc.cx(q[i+3], q[i+4])
        qc.cx(q[i+6], q[i+7])

        qc.cx(q[i], q[i+2])
        qc.cx(q[i+3], q[i+5])
        qc.cx(q[i+6], q[i+8])

    # Let the error Gates act
    for i in main_qubits:
            if chance(0.4):
                if randrange(2) == 0:
                    qc.x(q[i])
                    print('X Error gate acts on main qubit - {}'.format(i))
                else:
                    qc.z(q[i])
                    print('Z Error gate acts on main qubit - {}'.format(i))

    # Applying the error correction code
    for i in main_qubits:
        qc.cx(q[i], q[i+1])
        qc.cx(q[i+3], q[i+4])
        qc.cx(q[i+6], q[i+7])

        qc.cx(q[i], q[i+2])
        qc.cx(q[i+3], q[i+5])
        qc.cx(q[i+6], q[i+8])

        qc.ccx(q[i+2], q[i+1], q[i])
        qc.ccx(q[i+5],q[i+4],q[i+3])
        qc.ccx(q[i+8],q[i+7],q[i+6])

        qc.h(q[i])
        qc.h(q[i+3])
        qc.h(q[i+6])

        qc.cx(q[i], q[i+3])
        qc.cx(q[i], q[i+6])

        qc.ccx(q[i+6], q[i+3], q[i])


    qc.cx(q[0], q[9])

    qc.measure([0,9],[1,0])
    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)
    if counts.get('00') != None:
        n1 += 1
    else:
        n2 += 1

print('number of times we get |00> + |11>/root(2)', n1)
print('number of times we get anything else', n2)
# Out:
# iteration  0
# X Error gate acts on main qubit - 9
# iteration  1
# iteration  2
# iteration  3
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 9
# iteration  4
# iteration  5
# X Error gate acts on main qubit - 9
# iteration  6
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  7
# iteration  8
# X Error gate acts on main qubit - 9
# iteration  9
# iteration  10
# Z Error gate acts on main qubit - 0
# iteration  11
# X Error gate acts on main qubit - 0
# iteration  12
# Z Error gate acts on main qubit - 0
# iteration  13
# iteration  14
# Z Error gate acts on main qubit - 9
# iteration  15
# X Error gate acts on main qubit - 9
# iteration  16
# X Error gate acts on main qubit - 0
# iteration  17
# iteration  18
# iteration  19
# X Error gate acts on main qubit - 9
# iteration  20
# X Error gate acts on main qubit - 9
# iteration  21
# Z Error gate acts on main qubit - 9
# iteration  22
# iteration  23
# iteration  24
# iteration  25
# Z Error gate acts on main qubit - 0
# iteration  26
# iteration  27
# iteration  28
# X Error gate acts on main qubit - 0
# iteration  29
# Z Error gate acts on main qubit - 0
# iteration  30
# X Error gate acts on main qubit - 0
# iteration  31
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  32
# iteration  33
# Z Error gate acts on main qubit - 9
# iteration  34
# X Error gate acts on main qubit - 0
# iteration  35
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 9
# iteration  36
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  37
# iteration  38
# Z Error gate acts on main qubit - 0
# iteration  39
# Z Error gate acts on main qubit - 9
# iteration  40
# iteration  41
# X Error gate acts on main qubit - 0
# iteration  42
# Z Error gate acts on main qubit - 9
# iteration  43
# X Error gate acts on main qubit - 9
# iteration  44
# iteration  45
# iteration  46
# Z Error gate acts on main qubit - 0
# iteration  47
# Z Error gate acts on main qubit - 0
# iteration  48
# Z Error gate acts on main qubit - 0
# iteration  49
# X Error gate acts on main qubit - 9
# iteration  50
# Z Error gate acts on main qubit - 9
# iteration  51
# iteration  52
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  53
# iteration  54
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  55
# Z Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 9
# iteration  56
# Z Error gate acts on main qubit - 9
# iteration  57
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  58
# X Error gate acts on main qubit - 0
# iteration  59
# Z Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 9
# iteration  60
# X Error gate acts on main qubit - 0
# iteration  61
# Z Error gate acts on main qubit - 0
# iteration  62
# X Error gate acts on main qubit - 0
# iteration  63
# iteration  64
# iteration  65
# iteration  66
# X Error gate acts on main qubit - 9
# iteration  67
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  68
# X Error gate acts on main qubit - 9
# iteration  69
# iteration  70
# X Error gate acts on main qubit - 0
# iteration  71
# Z Error gate acts on main qubit - 0
# iteration  72
# iteration  73
# iteration  74
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  75
# iteration  76
# X Error gate acts on main qubit - 9
# iteration  77
# iteration  78
# iteration  79
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  80
# iteration  81
# X Error gate acts on main qubit - 0
# iteration  82
# Z Error gate acts on main qubit - 0
# iteration  83
# X Error gate acts on main qubit - 9
# iteration  84
# iteration  85
# X Error gate acts on main qubit - 9
# iteration  86
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 9
# iteration  87
# iteration  88
# X Error gate acts on main qubit - 9
# iteration  89
# X Error gate acts on main qubit - 9
# iteration  90
# iteration  91
# iteration  92
# X Error gate acts on main qubit - 0
# iteration  93
# X Error gate acts on main qubit - 0
# iteration  94
# iteration  95
# iteration  96
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 9
# iteration  97
# iteration  98
# iteration  99
# X Error gate acts on main qubit - 9
# number of times we get |00> + |11>/root(2) 100
# number of times we get anything else 0

# %% [markdown]
# **Making shor's code with lesser number of Qubits in total - using the same anicillia bits for both the main Qubits**

# %%
n1 = 0 # Number of times we obtain |00> + |11>/root(2), should be 100 as error correction is applied
n2 = 0 # Number of times any other result is obtained, should be 0 

for r in range(100):
    print('iteration ',r)
    q = QuantumRegister(10)
    # 0 and 1 are the main qubits
    # 2 -> 9 are the ancilliary qubits for both 0 and 1
    c = ClassicalRegister(2)
    qc = QuantumCircuit(q,c)

    qc.h(q[0])

    # Encoding as per Shor's Algorithm
    main_qubits = [0,1]
    for i in main_qubits:
        qc.cx(q[i], q[4])
        qc.cx(q[i], q[7])

        qc.h(q[0])
        qc.h(q[4])
        qc.h(q[7])

        qc.cx(q[i], q[2])
        qc.cx(q[4], q[5])
        qc.cx(q[7], q[8])

        qc.cx(q[i], q[3])
        qc.cx(q[4], q[6])
        qc.cx(q[7], q[9])

    # Let the error Gates act
        if chance(0.4):
            if randrange(2) == 0:
                qc.x(q[i])
                print('X Error gate acts on main qubit - {}'.format(i))
            else:
                qc.z(q[i])
                print('Z Error gate acts on main qubit - {}'.format(i))

    # Applying the error correction code
        qc.cx(q[i], q[2])
        qc.cx(q[4], q[5])
        qc.cx(q[7], q[8])

        qc.cx(q[i], q[3])
        qc.cx(q[4], q[6])
        qc.cx(q[7], q[9])

        qc.ccx(q[3], q[2], q[i])
        qc.ccx(q[6],q[5],q[3])
        qc.ccx(q[9],q[8],q[7])

        qc.h(q[i])
        qc.h(q[4])
        qc.h(q[7])

        qc.cx(q[i], q[4])
        qc.cx(q[i], q[7])

        qc.ccx(q[7], q[4], q[i])
        
        if i == 0:
            for p in range(2,10):
                qc.reset(q[p])


    qc.cx(q[0], q[1])
    qc.measure([0,9],[1,0])
    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)
    if counts.get('00') != None:
        n1 += 1
    else:
        n2 += 1

print('number of times we get |00> + |11>/root(2)', n1)
print('number of times we get anything else', n2)
# Out:
# iteration  0
# Z Error gate acts on main qubit - 1
# iteration  1
# iteration  2
# Z Error gate acts on main qubit - 1
# iteration  3
# iteration  4
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  5
# Z Error gate acts on main qubit - 0
# iteration  6
# iteration  7
# X Error gate acts on main qubit - 0
# iteration  8
# Z Error gate acts on main qubit - 0
# iteration  9
# iteration  10
# Z Error gate acts on main qubit - 0
# iteration  11
# Z Error gate acts on main qubit - 0
# iteration  12
# X Error gate acts on main qubit - 1
# iteration  13
# Z Error gate acts on main qubit - 0
# iteration  14
# X Error gate acts on main qubit - 1
# iteration  15
# iteration  16
# iteration  17
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 1
# iteration  18
# Z Error gate acts on main qubit - 0
# iteration  19
# Z Error gate acts on main qubit - 0
# iteration  20
# iteration  21
# iteration  22
# Z Error gate acts on main qubit - 1
# iteration  23
# X Error gate acts on main qubit - 0
# iteration  24
# Z Error gate acts on main qubit - 1
# iteration  25
# iteration  26
# X Error gate acts on main qubit - 0
# iteration  27
# Z Error gate acts on main qubit - 1
# iteration  28
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 1
# iteration  29
# X Error gate acts on main qubit - 1
# iteration  30
# iteration  31
# iteration  32
# iteration  33
# iteration  34
# Z Error gate acts on main qubit - 0
# iteration  35
# X Error gate acts on main qubit - 0
# iteration  36
# X Error gate acts on main qubit - 1
# iteration  37
# iteration  38
# iteration  39
# Z Error gate acts on main qubit - 0
# iteration  40
# iteration  41
# iteration  42
# Z Error gate acts on main qubit - 0
# iteration  43
# iteration  44
# iteration  45
# iteration  46
# iteration  47
# X Error gate acts on main qubit - 1
# iteration  48
# Z Error gate acts on main qubit - 0
# iteration  49
# iteration  50
# X Error gate acts on main qubit - 1
# iteration  51
# X Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 1
# iteration  52
# iteration  53
# X Error gate acts on main qubit - 0
# iteration  54
# iteration  55
# Z Error gate acts on main qubit - 0
# iteration  56
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  57
# iteration  58
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  59
# Z Error gate acts on main qubit - 1
# iteration  60
# iteration  61
# Z Error gate acts on main qubit - 0
# iteration  62
# X Error gate acts on main qubit - 1
# iteration  63
# X Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  64
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  65
# Z Error gate acts on main qubit - 1
# iteration  66
# X Error gate acts on main qubit - 1
# iteration  67
# Z Error gate acts on main qubit - 1
# iteration  68
# X Error gate acts on main qubit - 1
# iteration  69
# X Error gate acts on main qubit - 1
# iteration  70
# iteration  71
# X Error gate acts on main qubit - 1
# iteration  72
# Z Error gate acts on main qubit - 1
# iteration  73
# iteration  74
# Z Error gate acts on main qubit - 0
# iteration  75
# iteration  76
# Z Error gate acts on main qubit - 1
# iteration  77
# X Error gate acts on main qubit - 1
# iteration  78
# X Error gate acts on main qubit - 0
# iteration  79
# Z Error gate acts on main qubit - 0
# iteration  80
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  81
# X Error gate acts on main qubit - 0
# iteration  82
# iteration  83
# X Error gate acts on main qubit - 0
# iteration  84
# X Error gate acts on main qubit - 0
# iteration  85
# Z Error gate acts on main qubit - 0
# iteration  86
# iteration  87
# Z Error gate acts on main qubit - 0
# Z Error gate acts on main qubit - 1
# iteration  88
# iteration  89
# iteration  90
# Z Error gate acts on main qubit - 0
# iteration  91
# iteration  92
# Z Error gate acts on main qubit - 0
# iteration  93
# iteration  94
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  95
# iteration  96
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  97
# Z Error gate acts on main qubit - 0
# X Error gate acts on main qubit - 1
# iteration  98
# X Error gate acts on main qubit - 1
# iteration  99
# X Error gate acts on main qubit - 1
# number of times we get |00> + |11>/root(2) 100
# number of times we get anything else 0

# %% [markdown]
# **Steane's 7 bit code - Same ancilliary bits are used for both the main Qubits - (*Incomplete*: [*for more details*](https://github.com/rakaar/QOSF-Mentorship-Task/issues/1))**

# %%
q = QuantumRegister(14)
a = QuantumRegister(6)
c = ClassicalRegister(2)

qc = QuantumCircuit(q,a,c)


# 3 and 10 are our main qubits
qc.h(q[3])
main_qubits = [3,10]
    
for i in main_qubits:
    # encoding 
    qc.h(q[i-3])
    qc.h(q[i-2])
    qc.h(q[i-1])
    
    qc.barrier()

    qc.cx(q[i],q[i+1])
    qc.cx(q[i],q[i+2])
    
    qc.barrier()

    qc.cx(q[i-1],q[i])
    qc.cx(q[i-1],q[i+1])
    qc.cx(q[i-1],q[i+3])
    
    qc.barrier()

    qc.cx(q[i-2],q[i])
    qc.cx(q[i-2],q[i+2])
    qc.cx(q[i-2],q[i+3])
    
    qc.barrier()
    
    qc.cx(q[i-3],q[i+1])
    qc.cx(q[i-3],q[i+2])
    qc.cx(q[i-3],q[i+3])
    
    qc.barrier()


    # Let error gates act
    if chance(0.4):
        if randrange(2) == 0:
            qc.x(q[i])
            print('X Error gate acts on main qubit - {}'.format(i))
        else:
            qc.z(q[i])
            print('Z Error gate acts on main qubit - {}'.format(i))
    
    
    qc.barrier()
    
    # Decoding
    for p in range(0,6):
        qc.h(a[p])

    qc.cz(a[0], q[i+3])
    qc.cz(a[0], q[i+2])
    qc.cz(a[0], q[i+1])
    qc.cz(a[0], q[i-3])
    
    qc.barrier()
    
    qc.cz(a[1], q[i+3])
    qc.cz(a[1], q[i+2])
    qc.cz(a[1], q[i])
    qc.cz(a[1], q[i-2])
    
    qc.barrier()
    
    qc.cz(a[2], q[i+3])
    qc.cz(a[2], q[i+1])
    qc.cz(a[2], q[i])
    qc.cz(a[2], q[i-1])
    
    
    qc.cx(a[3], q[i+3])
    qc.cx(a[3], q[i+2])
    qc.cx(a[3], q[i+1])
    qc.cx(a[3], q[i-3])
    
    
    qc.cx(a[4], q[i+3])
    qc.cx(a[4], q[i+2])
    qc.cx(a[4], q[i])
    qc.cx(a[4], q[i-2])
    
    
    qc.cx(a[5], q[i+3])
    qc.cx(a[5], q[i+1])
    qc.cx(a[5], q[i])
    qc.cx(a[5], q[i-1])
    
    for p in range(0,6):
        qc.h(a[p])
    
    syndrome_bits = []
    print('Syndrome bits')
    for k in range(5,-1,-1):
        qc.measure(a[k], c[1])
        job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
        counts = job.result().get_counts(qc)
        syndrome_bits.append(list(counts.keys())[0][0])
    syndrome_bits = [ int(syn_bit) for syn_bit in syndrome_bits[::-1]]
    print(syndrome_bits)
    
    # Conditional Correction of Z-gate 
    if (not syndrome_bits[3]) and syndrome_bits[4] and syndrome_bits[5]:
        qc.z(q[i])
        print('Z-gate to be applied on {} qubit'.format(i))
        
    # Condition correction of X-gate
    if (not syndrome_bits[0]) and syndrome_bits[1] and syndrome_bits[2]:
        qc.x(q[i])
        print('X-gate need to be applied on {} qubit'.format(i))
    
    
    qc.measure(q[i],c[1])
    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)
    
    qc.draw(output='mpl', reverse_bits=True, filename='steane_code_for_bit_{}.png'.format(i))
    if i == 3:
        for index_a in range(6):
            qc.reset(a[index_a])

            
qc.cx(q[3], q[10])
qc.measure([3,10],[1,0])
job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
counts = job.result().get_counts(qc)
print('counts ', counts)
# Out:
# Z Error gate acts on main qubit - 3
# Syndrome bits
# [0, 0, 0, 0, 1, 1]
# Z-gate to be applied on 3 qubit
# Z Error gate acts on main qubit - 10
# Syndrome bits
# [0, 0, 0, 0, 1, 1]
# Z-gate to be applied on 10 qubit
